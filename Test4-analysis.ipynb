# %%
# %matplotlib inline
import sys
from lib.restartable_pendulum import RestartablePendulumEnv
from lib import state_rep_torch as srt
import gym
import numpy as np
from matplotlib import pyplot as plt
import torch
from lib import utils
from lib import encoder_wrappers as ew

# specify environment information
n_repeats = 3 # step the environment this many times for each action, concatenate the pixel observations
env = RestartablePendulumEnv(repeats=n_repeats,pixels=True)

save_dir = "./"

# %% [markdown]
# # Forward (Pixels)

# %%
n_repeats = 2
env = RestartablePendulumEnv(repeats=n_repeats,pixels=True)

net = torch.load(save_dir+"/soft_fwd.net")

# what follows is code to visualize the representations
d = 3 # must match the final entry in layers
n_samps = 500
env = ew.TorchEncoderWrapper(env,net.encoder,np.eye(d))
X = np.empty((n_samps,d))
for i,ang in enumerate(np.linspace(0,2*np.pi,n_samps)): # go through the angles from 0 to 2pi
    X[i,:] = env.reset(state=[ang,0])
    #env.render()
xhat = utils.visualize_trajectory_aligned(X)

# %%
_ = utils.visualize_trajectory(X)

# %%
n_repeats = 2
env = RestartablePendulumEnv(repeats=n_repeats,pixels=True)

net = torch.load(save_dir+"/soft_fwd_2.net")

# what follows is code to visualize the representations
d = 3 # must match the final entry in layers
n_samps = 500
env = ew.TorchEncoderWrapper(env,net.encoder,np.eye(d))
X = np.empty((n_samps,d))
for i,ang in enumerate(np.linspace(0,2*np.pi,n_samps)): # go through the angles from 0 to 2pi
    X[i,:] = env.reset(state=[ang,0])
    #env.render()
xhat = utils.visualize_trajectory_aligned(X)

# %%
_ = utils.visualize_trajectory(X)

# %%
#xhat
# import scipy.linalg as la
# U, Si, VT = la.svd(X, full_matrices=False)
# U
# Out:
# array([[-0.04011305,  0.04191965,  0.00955585, -0.0206963 , -0.0266488 ],
#        [-0.04232679,  0.02157825,  0.04979223, -0.00744604, -0.02465563],
#        [-0.04232679,  0.02157825,  0.04979223, -0.00744604, -0.02465563],
#        ...,
#        [-0.04011305,  0.04191965,  0.00955585, -0.0206963 , -0.0266488 ],
#        [-0.04011305,  0.04191965,  0.00955585, -0.0206963 , -0.0266488 ],
#        [-0.04011305,  0.04191965,  0.00955585, -0.0206963 , -0.0266488 ]])

# %% [markdown]
# # Forward + Reward (Pixels)

# %%
n_repeats=3
env = RestartablePendulumEnv(repeats=n_repeats,pixels=True)

# what follows is code to visualize the representations
#net_fwd_rew = torch.load(save_dir+"/soft_fwd_rew_1.0net")
net_fwd_rew = torch.load(save_dir+"/soft_fwd_rew.net")

d = 3 # must match the final entry in layers
n_samps = 500
#env = ew.TorchEncoderWrapper(env,net.encoder,np.eye(d))
X = np.empty((n_samps,d))
for i,ang in enumerate(np.linspace(0,2*np.pi,n_samps)): # go through the angles from 0 to 2pi
    #print(env.reset(state=[ang,0]))
    obs=env.reset(state=[ang,0])
    #print(obs)
    with torch.no_grad():
        X[i,:] = net_fwd_rew.encoder.forward(torch.from_numpy(np.expand_dims(obs,0)).float())
xhat = utils.visualize_trajectory_aligned(X)

# %%
xhat = utils.visualize_trajectory(X)

# %% [markdown]
# # Rewards (only)

# %%
# what follows is code to visualize the representations

net_rew = torch.load(save_dir+"/rew.net")

d = 5 # must match the final entry in layers
n_samps = 500
#env = ew.TorchEncoderWrapper(env,net.encoder,np.eye(d))
X = np.empty((n_samps,d))
for i,ang in enumerate(np.linspace(0,2*np.pi,n_samps)): # go through the angles from 0 to 2pi
    #print(env.reset(state=[ang,0]))
    obs=env.reset(state=[ang,0])
    #print(obs)
    with torch.no_grad():
        X[i,:] = net_rew.encoder.forward(torch.from_numpy(np.expand_dims(obs,0)).float())
xhat = utils.visualize_trajectory_aligned(X)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-29b9bcb652ca> in <module>
#      12     #print(obs)
#      13     with torch.no_grad():
# ---> 14         X[i,:] = net_rew.encoder.forward(torch.from_numpy(np.expand_dims(obs,0)).float())
#      15 xhat = utils.visualize_trajectory_aligned(X)
#
# /mnt/c/Users/holden/Documents/CS/ml/LinearizingStateRepresentation/lib/state_rep_torch.py in forward(self, x)
#     518         z = self.sigma(self.conv1(x))
#     519         z = self.sigma(self.conv2(z))
# --> 520         z = z.view(-1, self.size)
#     521         for layer in self.layers[:-1]:
#     522             z = self.sigma(layer(z))
#
# RuntimeError: shape '[-1, 2112]' is invalid for input of size 1344

# %% [markdown]
# # Matplotlib test

# %%
# %matplotlib inline
# importing matplotlib module  
from matplotlib import pyplot as plt  
  
# x-axis values  
x = [5, 2, 9, 4, 7]  
  
# Y-axis values  
y = [10, 5, 8, 4, 2]  
  
# Function to plot  
plt.plot(x, y)  
  
# function to show the plot  
plt.show()

# %%
A=np.asarray([[1,2],[3,4]])
print(np.mean(A, axis=0))
A - np.mean(A,axis=0)
# Out:
# [2. 3.]
# array([[-1., -1.],
#        [ 1.,  1.]])
